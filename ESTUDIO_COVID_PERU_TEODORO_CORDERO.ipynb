# %% [markdown]
# <a href="https://colab.research.google.com/github/teodoro-cordero/pandas/blob/master/ESTUDIO_COVID_PERU_TEODORO_CORDERO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt # importando matplotlib
import seaborn as sns # importando seaborn
import numpy as np # importando numpy
from scipy import stats # importando scipy.stats
import pandas as pd # importando pandas
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('https://raw.githubusercontent.com/teodoro-cordero/pandas/master/positivos_covid.csv', encoding='latin-1')
df.head() # longley dataset
# Out:
#                                UUID DEPARTAMENTO  ...       SEXO FECHA_RESULTADO
# 0  7320cabdc1aaca6c59014cae76a134e6         LIMA  ...   FEMENINO       4/05/2020
# 1  e81602051997ace8340bb8c18fe24c65         LIMA  ...   FEMENINO       1/05/2020
# 2  cecdbf10074dbc011ae05b3cbd320a6f         LIMA  ...  MASCULINO      30/04/2020
# 3  71ecb6bccb248b0bb2ac72ed51b5e979       ANCASH  ...   FEMENINO      16/05/2020
# 4  566af4276cbe9359abe93f9aa86396c3         LIMA  ...  MASCULINO       2/05/2020
#
# [5 rows x 8 columns]

# %%
df.describe()
# Out:
#                EDAD
# count  12173.000000
# mean      46.794545
# std       17.442034
# min        0.000000
# 25%       33.000000
# 50%       46.000000
# 75%       59.000000
# max      103.000000

# %%
d1=df["PROVINCIA"]
d2=df["EDAD"]
d3=df["SEXO"]
d4=df["DEPARTAMENTO"]

# %%
# Gráfico de tarta de pasajeros del Titanic
plot = d4.value_counts().plot(kind='pie', autopct='%.2f', 
                                            figsize=(10,10),
                                            title='contagiados por provincias')

# %%
pd.crosstab(index=d1,
            columns=d4, margins=True)
# Out:
# DEPARTAMENTO   AMAZONAS  ANCASH  APURIMAC  ...  TUMBES  UCAYALI    All
# PROVINCIA                                  ...
# ABANCAY               0       0         5  ...       0        0      5
# ACOMAYO               0       0         0  ...       0        0      2
# ALTO AMAZONAS         0       0         0  ...       0        0    175
# ANDAHUAYLAS           0       0         1  ...       0        0      1
# AREQUIPA              0       0         0  ...       0        0    260
# ...                 ...     ...       ...  ...     ...      ...    ...
# VIRU                  0       0         0  ...       0        0      8
# YAULI                 0       0         0  ...       0        0     22
# YAUYOS                0       0         0  ...       0        0      6
# ZARUMILLA             0       0         0  ...       6        0      6
# All                  69     364         6  ...      20      140  12177
#
# [104 rows x 26 columns]

# %%
plot = pd.crosstab(index=d4,
            columns=d3).apply(lambda r: r/r.sum() *100,
                                              axis=1).plot(kind='bar')

# %%
plot = pd.crosstab(index=d4,
            columns=d3
                  ).apply(lambda r: r/r.sum() *100,
                          axis=0).plot(kind='bar', stacked=True)

# %%
plot = pd.crosstab(index=d2,
            columns=d3
                  ).apply(lambda r: r/r.sum() *100,
                          axis=0).plot(kind='bar', stacked=True)

# %%
plot = d4.value_counts().plot(kind='bar',
                                            title='contagios covid')

# %%
# Gráfico de barras de pasajeros del Titanic
plot = d3.value_counts().plot(kind='bar',
                                            title='contagios covid')

# %%
g = sns.jointplot(x="EDAD", y="DEPARTAMENTO",
                 data=df, kind="reg",
                 line_kws={'color':'green'},
                 scatter_kws={'alpha': 0.33})
g.fig.set_size_inches(8, 8)
g.fig.suptitle("EDAD vs DEPARTAMENTO joinplot\nfor every known Pokemon species",
               fontsize=16, weight="bold", y=1.05)
Text(0.5,1.05,'EDAD vs DEPARTAMENTO joinplot\nfor every known Pokemon species')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-d7e02df64e03> in <module>()
#       2                  data=df, kind="reg",
#       3                  line_kws={'color':'green'},
# ----> 4                  scatter_kws={'alpha': 0.33})
#       5 g.fig.set_size_inches(8, 8)
#       6 g.fig.suptitle("EDAD vs DEPARTAMENTO joinplot\nfor every known Pokemon species",
#
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2322
#    2323         marginal_kws.setdefault("color", color)
# -> 2324         grid.plot_marginals(distplot, **marginal_kws)
#    2325
#    2326         joint_kws.setdefault("color", color)
#
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py in plot_marginals(self, func, **kwargs)
# ...

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='informe.html')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-c477bd28b4bf> in <module>()
#       1 from pandas_profiling import ProfileReport
# ----> 2 prof = ProfileReport(df)
#       3 prof.to_file(output_file='informe.html')
#
# /usr/local/lib/python3.6/dist-packages/pandas_profiling/__init__.py in __init__(self, df, **kwargs)
#      64         sample = kwargs.get('sample', df.head())
#      65
# ---> 66         description_set = describe(df, **kwargs)
#      67
#      68         self.html = to_html(sample,
#
# /usr/local/lib/python3.6/dist-packages/pandas_profiling/describe.py in describe(df, bins, check_correlation, correlation_threshold, correlation_overrides, check_recoded, pool_size, **kwargs)
#     390             if name not in names:
#     391                 names.append(name)
# --> 392     variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# ...

# %%
plt.plot(d1.value_counts(), d3.value_counts(), label='data science')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-7785f806e0e5> in <module>()
# ----> 1 plt.plot(d1.value_counts(), d3.value_counts(), label='data science')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ...

# %%
sns.pairplot(df)

# %%
d4.value_counts()
# Out:
# LIMA             6927
# CALLAO           1276
# LORETO           1021
# LA LIBERTAD       485
# ANCASH            364
# LAMBAYEQUE        359
# ICA               337
# AREQUIPA          276
# SAN MARTIN        194
# UCAYALI           140
# JUNIN             130
# AYACUCHO          126
# PIURA             121
# CAJAMARCA         111
# AMAZONAS           69
# CUSCO              68
# HUANUCO            55
# MADRE DE DIOS      46
# TUMBES             20
# HUANCAVELICA       14
# TACNA              13
# PUNO                9
# PASCO               8
# APURIMAC            6
# MOQUEGUA            2
# Name: DEPARTAMENTO, dtype: int64

# %%
d1.value_counts()
# Out:
# LIMA                      6146
# CALLAO                    1258
# MAYNAS                     721
# TRUJILLO                   471
# CAÑETE                     339
#                           ...
# CHUMBIVILCAS                 1
# GENERAL SANCHEZ CERRO        1
# CASTILLA                     1
# CHUPACA                      1
# DANIEL ALCIDES CARRION       1
# Name: PROVINCIA, Length: 103, dtype: int64

# %%
d3.value_counts()
# Out:
# MASCULINO    7305
# FEMENINO     4871
# Name: SEXO, dtype: int64

# %%
d2.value_counts()
# Out:
# 32.0     291
# 38.0     284
# 41.0     275
# 34.0     267
# 35.0     265
#         ...
# 96.0       2
# 97.0       2
# 103.0      1
# 100.0      1
# 99.0       1
# Name: EDAD, Length: 101, dtype: int64

# %%
plot = d3.value_counts().plot(kind='bar',
                                            title='contagios covid sexo')

# %%
d4.value_counts().describe()
# Out:
# count      25.000000
# mean      487.080000
# std      1377.521474
# min         2.000000
# 25%        20.000000
# 50%       121.000000
# 75%       337.000000
# max      6927.000000
# Name: DEPARTAMENTO, dtype: float64

# %%
d2.value_counts().describe()
# Out:
# count    101.000000
# mean     120.524752
# std       96.693495
# min        1.000000
# 25%       25.000000
# 50%      102.000000
# 75%      227.000000
# max      291.000000
# Name: EDAD, dtype: float64

# %%
d3.value_counts().describe()
# Out:
# count       2.000000
# mean     6088.000000
# std      1721.097905
# min      4871.000000
# 25%      5479.500000
# 50%      6088.000000
# 75%      6696.500000
# max      7305.000000
# Name: SEXO, dtype: float64

# %%
df.count()
# Out:
# UUID               12177
# DEPARTAMENTO       12177
# PROVINCIA          12177
# DISTRITO           12177
# METODODX           12176
# EDAD               12173
# SEXO               12176
# FECHA_RESULTADO    12176
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12177 entries, 0 to 12176
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UUID             12177 non-null  object
#  1   DEPARTAMENTO     12177 non-null  object
#  2   PROVINCIA        12177 non-null  object
#  3   DISTRITO         12177 non-null  object
#  4   METODODX         12176 non-null  object
#  5   EDAD             12173 non-null  float64
#  6   SEXO             12176 non-null  object
#  7   FECHA_RESULTADO  12176 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 761.2+ KB

# %%
datos_1 = d1.value_counts()
datos_2 = d2.value_counts()
datos_3 = d3.value_counts()
datos_4 = d4.value_counts()

datos_graf = [datos_1, datos_2, datos_3, datos_4]

# Creando el objeto figura
fig = plt.figure(1, figsize=(9, 6))

# Creando el subgrafico
ax = fig.add_subplot(111)

# creando el grafico de cajas
bp = ax.boxplot(datos_graf)

# visualizar mas facile los atípicos
for flier in bp['fliers']:
    flier.set(marker='o', color='red', alpha=0.5)
# los puntos aislados son valores atípicos

# %%
sns.heatmap(df.corr(), annot=True, fmt='.2f')

# %%
plt.plot(d2, d2.value_counts(10), label='data science')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-28dee189432c> in <module>()
#       1
# ----> 2 plt.plot(d2, d2.value_counts(10), label='data science')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ...
